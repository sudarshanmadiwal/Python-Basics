# %% [markdown]
# # BASICS
# ## Hello Sudarshan
# - Its 1st day of Python programming
# ### LETEX is used for writing mathematical formula
#     - $(a+b)^2$
#     #### here we use start and end with dollar sign and in between write formula

# %%
print('hello world')
# Out:
# hello world

# %% [markdown]
# ## Constants
# ###  Fixed values such as numbers, letters, and strings, are called "Constants" because their value does not change

# %%
x=10
print(x)
# Out:
# 10

# %%
y=20.55
print(y)
# Out:
# 20.55

# %%
string = "hello world!"
print(string) # string constants use single quotes(') or double quotes(")
# Out:
# hello world!

# %% [markdown]
# ![image.png](attachment:image.png)

# %%
X = 12.2
print(X)
# Out:
# 12.2

# %%
X = 20
print(X)
# Out:
# 20

# %% [markdown]
# ![image.png](attachment:image.png)

# %%
class = a
print(class)# you cannot use reserved words as variables here class is reserved variables
# Out:
#   File "<ipython-input-7-1dd35638c678>", line 1
#     class = a
#           ^
# SyntaxError: invalid syntax

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# #  Arithmaatic Operators
# - Addition +
# - Substraction -
# - Multiplication *
# - Division /
# - Integer division //
# - Modulus %
# - Power **

# %%
a = 5
b = 6
add = a+b
sub = b-a
mul = a*b
div = a/b
int_dev = b//a
mod = a%b
power = a**2

# %%
print(add)
print(sub)
print(mul)
print(div)
print(int_dev)
print(mod)
print(power)
# Out:
# 11
# 1
# 30
# 0.8333333333333334
# 1
# 5
# 25

# %%
2**4
# Out:
# 16

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)

# %%
x = 1 +2**3 /4*5
print(x)
# Out:
# 11.0

# %% [markdown]
# Python knows the difference between an integer number and a string
# for example "+" means addition

# %%
add  = 4 + 4
print(add)# results addition of numbers
# Out:
# 8

# %%
# where as if add strings result is concateneated
string = "hello" + " world!"
print(string)
# Out:
# hello world!

# %%
string1 = "hello "+ 5 # we cannot concatenate number and string 
print(string1)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-14-a67c8b2fd272> in <module>
# ----> 1 string1 = "hello "+ 5 # we cannot concatenate number and string
#       2 print(string1)
#
# TypeError: can only concatenate str (not "int") to str

# %% [markdown]
# if we want to concatenate then we have to change the type of number to string

# %%
string1 = "hello "+ str(5) # number 5 is converted to string type
print(string1)
# Out:
# hello 5

# %% [markdown]
# ### types

# %% [markdown]
# #### numbers have two main types
# - integers are whole numbers
# - floating point numbers have decimal parts: -2.5, 98.5
# - to check we use syntax  type()

# %%
print(type(5))
print(type(5.5))
# Out:
# <class 'int'>
# <class 'float'>

# %% [markdown]
# #### type conversion

# %%
print(10+50)
print(float(10)+50) # conversion integer 10 to float 10 the result is floating
# Out:
# 60
# 60.0

# %%
i = 43
print(type(i))
# Out:
# <class 'int'>

# %%
f = float(i)
print(f)
print(type(f))
# Out:
# 43.0
# <class 'float'>

# %%
# integer division produces a floating result
print(16/2)
# Out:
# 8.0

# %% [markdown]
# #### String conversions

# %%
num = '59' # number is string here
print(type(num))
# Out:
# <class 'str'>

# %%
print(num+1)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-22-337215e09d2c> in <module>
# ----> 1 print(num+1)
#
# TypeError: can only concatenate str (not "int") to str

# %%
inum = int(num)# coverting to int 
print(type(inum))
print(inum+1)
# Out:
# <class 'int'>
# 60

# %%
string = "hello world!"
istring = int(string) # you will get an error if the string does not contain numeric charecters
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-24-5db85e42c15d> in <module>
#       1 string = "hello world!"
# ----> 2 istring = int(string) # you will get an error if the string does not contain numeric charecters
#
# ValueError: invalid literal for int() with base 10: 'hello world!'

# %% [markdown]
# # User Input
# - we can instruct python to pause and read data from user using the "input()" function
# - the input() function returns a string type

# %%
x = input('enter a number:')
print('you have enterd ',x)
# Out:
# enter a number:5
# you have enterd  5

# %%
print(type(x))
# Out:
# <class 'str'>

# %%
x = int(input('enter a number:')) # converting to int type 
print('you have enterd ',x)
print(type(x))
# Out:
# enter a number:5
# you have enterd  5
# <class 'int'>

# %% [markdown]
# ### To check the memory location we use id() function

# %%
print(id(x))
# Out:
# 140715816034832

# %%
a=10

# %%
b=10

# %%
print(id(a),id(b))
# Out:
# 140715816034992 140715816034992

# %% [markdown]
# - here the variables a and b are assigned with same values therefore memory loacation of the two variables are same

# %% [markdown]
# # Basic utility functions
# - max()
# - min()
# - len()

# %%
m = max(1,2,3,4,6,7,90,88)
n = min(8,4,5,23,3,22,4,6,6)
l = 'hfnjfgjh'
print(m)
print(n)
print(len(l))
# Out:
# 90
# 3
# 8

# %%
ma = max('suDarshan')
print(ma) # its decide on ascii values
# Out:
# u

# %%
# to check ascii values we use chr() function
# In ascii values alphabets are in the range of 65 to 122
for i in range(65,123):
    print(i ,'is ascii value of',chr(i))
# Out:
# 65 is ascii value of A
# 66 is ascii value of B
# 67 is ascii value of C
# 68 is ascii value of D
# 69 is ascii value of E
# 70 is ascii value of F
# 71 is ascii value of G
# 72 is ascii value of H
# 73 is ascii value of I
# 74 is ascii value of J
# 75 is ascii value of K
# 76 is ascii value of L
# 77 is ascii value of M
# 78 is ascii value of N
# 79 is ascii value of O
# 80 is ascii value of P
# 81 is ascii value of Q
# 82 is ascii value of R
# 83 is ascii value of S
# 84 is ascii value of T
# 85 is ascii value of U
# 86 is ascii value of V
# 87 is ascii value of W
# 88 is ascii value of X
# 89 is ascii value of Y
# 90 is ascii value of Z
# 91 is ascii value of [
# 92 is ascii value of \
# 93 is ascii value of ]
# 94 is ascii value of ^
# 95 is ascii value of _
# 96 is ascii value of `
# 97 is ascii value of a
# 98 is ascii value of b
# 99 is ascii value of c
# 100 is ascii value of d
# 101 is ascii value of e
# 102 is ascii value of f
# 103 is ascii value of g
# ...

# %%
97+26
# Out:
# 123

# %%
## find area of the square of side 3meters
side = int(input("enter side of the square: "))
area = side * side 
print("area of square is: ",area)
# Out:
# enter side of the square: 5
# area of square is:  25

# %%
import math

# %% [markdown]
# -  This module provides access to the mathematical functions
# -  https://docs.python.org/3/library/math.html for more details

# %%
radius = int(input('enter the radius:'))
area = print('area is',math.pi * math.pow(radius,2))
# Out:
# enter the radius:5
# area is 78.53981633974483

# %%
a= int(input('enter the length of a '))
b= int(input('enter the length of b '))
c= int(input('enter the length of c '))
s = (a+b+c)/2
print("area of traingle is:",math.sqrt(s*(s-a)*(s-b)*(s-c)))
# Out:
# enter the length of a 5
# enter the length of b 5
# enter the length of c 5
# area of traingle is: 10.825317547305483

# %% [markdown]
# # Formating with print()

# %%
print("hello")
print("world")
# Out:
# hello
# world

# %%
print("hello",end='3  4')
print("world")
# Out:
# hello3  4world

# %%
x = 10
y =30
total = x + y
print('value of x is',x,'value of y is',y,'value of total is',total)
print('value of x is', x,'value of y is', y,'value of total is',total,sep='\n')
# Out:
# value of x is 10 value of y is 30 value of total is 40
# value of x is
# 10
# value of y is
# 30
# value of total is
# 40

# %% [markdown]
# # .format()

# %%
a = 10
b = 20
print('the value of a is {} and value of b is {}'.format(a,b))
# Out:
# the value of a is 10 and value of b is 20

# %%
a = 5/3
a
# Out:
# 1.6666666666666667

# %%
print('value of a is: {0:0.2f}'.format(a))
# Out:
# value of a is: 1.67

# %%
b = 6/4
print('value of b is: {1:0.2f}, value of a is :{0}'.format(a,b))
# Out:
# value of b is: 1.50, value of a is :1.6666666666666667

# %% [markdown]
# # Realational operators
# - takes two operands
# - Results in boolean value
# - Available  symbols:  >, <, =, <=, >=, !=, ==

# %%
a = 10
b = 20
result = a<b
print(result)
# Out:
# True

# %% [markdown]
# # logical operators
# - Operands and Results are boolean values
# - Three operators AND, OR, NOT
# - The operators $and$ and $or$ are binary operators ,$not$ is a unary operator

# %%
x = 10
y = 20
z = 15

p = x<y and y<z
print(p)
# Out:
# False

# %%
a =10 
b = 10
p = a is b
print(p)
# Out:
# True

# %%
a = True
b =not a
print(b)
# Out:
# False

# %%
a= False
b= not a
print(b)
# Out:
# True
